# %% [markdown]
# NUMPY DATA TYPE AND TYPE CASTING

# %%
import numpy as np

# %%
arr =np.array([1,2,4.1,3])
arr
# Out:
# array([1. , 2. , 4.1, 3. ])

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
lst=["ram",1,2.3,44]
b=np.array(lst)
b
# Out:
# array(['ram', '1', '2.3', '44'], dtype='<U32')
