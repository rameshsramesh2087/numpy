# %% [markdown]
# NUMPY DATA TYPE AND TYPE CASTING

# %%
import numpy as np

# %%
arr =np.array([1,2,4.1,3])
arr
# Out:
# array([1. , 2. , 4.1, 3. ])

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
lst=["ram",1,2.3,44]
b=np.array(lst)
b
# Out:
# array(['ram', '1', '2.3', '44'], dtype='<U32')

# %%
import numpy as np

a=np.array([1,22,33,12,55])
a.dtype
# Out:
# dtype('int32')

# %%
b=np.array([1.2,1.4] ,dtype=np.int64)
b.dtype
# Out:
# dtype('int64')
