# %%
import numpy as np
a=np.array([1,2,3])
print(type(a))
print(a.ndim)
# Out:
# <class 'numpy.ndarray'>
# 1

# %%
b=np.array([[[[1,2,3],[1,3,2],[5,3,5]]]])
print(b.ndim)
# Out:
# 4

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
arr=np.array([1,22,3,4])
print(arr.ndim)
# Out:
# 1

# %%
arr=np.array(20)
print(arr.ndim)
# Out:
# 0

# %%
arr=np.array([[[[1,2,3,4],[2,3,4,5],[1,2,3,4]]]])
print(arr)
print(arr.ndim)
print(arr.shape)
# Out:
# [[[[1 2 3 4]
#    [2 3 4 5]
#    [1 2 3 4]]]]
# 4
# (1, 1, 3, 4)

# %%
range=np.arange(1,30,3)
print(range)
# Out:
# [ 1  4  7 10 13 16 19 22 25 28]
