# %%
import numpy as np  #alias ->np common use cases
np.array([1,3,4,5])
# Out:
# array([1, 3, 4, 5])

# %%
# dimensions and shapes of array

arr=np.array(34)
arr.ndim
# Out:
# 0

# %%
arr1=np.array([1,2,3,4])
arr1.ndim
# Out:
# 1

# %%
#  dimensions
a=np.array([])
a.ndim
# Out:
# 1

# %%
a=np.array([[[[]]]])
a.ndim
a.shape
# Out:
# (1, 1, 1, 0)

# %%
b=np.array([[[1,2,3,4],[1,2,3,4]]])
b.shape
# Out:
# (1, 2, 4)

# %%
b=np.array([[[[1,2,3,4],[1,2,3,3]]]])
b.shape
# Out:
# (1, 1, 2, 4)
