# %% [markdown]
# python command are used to make the code more redable.explain python codes.
# python command start hash # symbol
#
# miltiline command python does not has multiline command if want to create a multiline command can use
# multiline string syntax use to create a multiline command.

# %%
#ramesh rajesh
'''i am ramesh'''
# Out:
# 'i am ramesh'

# %% [markdown]
# keywors in python are reserved words that have a special meaning and sever special purpose in python language

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# variable must start with a letters or underscore. variable cannot start  numbers or digits.
# can included number and letters underscore .no space allowed .cannot use python keywords
# python is a case sensitive(name != Name)

# %%
a=22
b=33
print(a+b)
# Out:
# 55

# %%
a=c=b=1100
print(a)
print(b)
print(c)
# Out:
# 1100
# 1100
# 1100

# %%
a,b,c=33,22,11
print(a)
print(b)
print(c)
# Out:
# 33
# 22
# 11

# %% [markdown]
# type casting
# .if want specific data type of variable  you can use

# %%
a=int(33.44)
b=str(33)
c=float(33)
print(a,b,c)
# Out:
# 33 33 33.0

# %%
a=33
b=66
c=33.44
a=float(a)
b=str(b)
c=int(c)
print(a)
print(c)
print(b)
# Out:
# 33.0
# 33
# 66

# %% [markdown]
# casting.you can get data type of variable with type().

# %%
a=22.0
b='word'
c=2j+4
d=100
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(a,b,c,d)
# Out:
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'int'>
# 22.0 word (4+2j) 100

# %%
a=20
del a

# %%
# swapping
a=33
b=44
a,b=b,a
print(a)
print(b)
# Out:
# 44
# 33

# %%
name='ramesh'
length=len(name)
print(length)
# Out:
# 6
