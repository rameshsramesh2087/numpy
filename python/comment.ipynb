# %% [markdown]
# python comment explain python codes.
# comments can make code more redable.
# python comment create hash #

# %%
# python comment
print("hello world")
# Out:
# hello world

# %% [markdown]
# multiline comment.
#
# 1) python does not have a multiline comments syntax.
# 2)but multiline string using comment can be used a python comment

# %%
'''hello
world 
'''
# Out:
# 'hello\nworld \n'

# %%
'''hello world'''
print('hello world!')
# Out:
# hello world!

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
