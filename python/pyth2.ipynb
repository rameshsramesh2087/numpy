# %% [markdown]
# primitive data type
# that are basic buil in data type in python that hold single value ,int,float,str,complex

# %% [markdown]
# non primitive data type . that are complex data type hold multipe values and different data type, list,tuple,dictionary,sets
