# %%
# arithmetic
a=30
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 33
# 27
# 90
# 10.0
# 10
# 0
# 27000

# %%
a=2
a+=1
print(a)
a-=1
print(a)
a*=5
print(a)
a**=3
print(a)
a%=3
print(a)
a+=45
print(a)
a/=3
print(a)
a//=2
print(a)
# Out:
# 3
# 2
# 10
# 1000
# 1
# 46
# 15.333333333333334
# 7.0

# %%
# comparision 
a=22
b=33
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(b<=a)
# Out:
# False
# True
# False
# True
# False
# False

# %%
a=99
b=100
print(a>=b)
print(a<=b)
print(b>=a)
print(b<=a)
# Out:
# False
# True
# True
# False

# %%
# logical operator
print(33>22 and 44<100)
print(33<22 and 33>3)
# Out:
# True
# False

# %%
print(33<1 or 55<100)
print(1<2 or 33>100)
# Out:
# True
# True

# %%
print(not(2>5 and 33>100))
print(not(2<5 and 33<100))
# Out:
# True
# False

# %%
# identity
a=['apple','banana']
b=['apple','banana']
c=a
print(a is b)
print(a is c)
print(b is c)
print(a is not b)
# Out:
# False
# True
# False
# True

# %%
a=257
b=256
c=257
d=256
print(d is b)
print(a is c)
# Out:
# True
# False

# %%
# membership operator
a=['apple','orange']
print('apple' in a)
print('banana' not in a)
# Out:
# True
# True

# %%
# bitwise operator
a=6
b=3
print(a&b)
# Out:
# 2

# %%
a=3
b=4
print(a|b)
# Out:
# 7

# %%
a=3
b=5
print(a^b)
# Out:
# 6

# %%
print(12>>10)
# Out:
# 0

# %%
print(12<<3)
# Out:
# 96
