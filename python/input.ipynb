# %%
a=input("enter number:")
b=input("enter number:")
print(a+b)
# Out:
# 33

# %%
a=int(input("enter number:"))
b=int(input("enter number:"))
print(a+b)
# Out:
# 6

# %%
import sys
full_name=sys.argv[1]

email=full_name.lower().replace(' ','.')+"@company.com"

print("\n----yourprofile-----")
print("full name:",full_name)
print("generated_email:",email)
# Out:
# ----yourprofile-----
# full name: --f=c:\Users\rames\AppData\Roaming\Code\User\globalStorage\ms-toolsai.jupyter\version-2025.9.1\jupyter\runtime\kernel-v363d41350a3f89071d32832a4ebc34c5f30d45318.json
# generated_email: --f=c:\users\rames\appdata\roaming\code\user\globalstorage\ms-toolsai.jupyter\version-2025.9.1\jupyter\runtime\kernel-v363d41350a3f89071d32832a4ebc34c5f30d45318.json@company.com
