# %%
host_name="ramesh"
print(host_name.capitalize())
print(host_name.upper())
print(host_name.lower())
print(host_name.title())
# Out:
# Ramesh
# RAMESH
# ramesh
# Ramesh

# %%
a="""this ia a multiline
string syntax
use to type multiple lines"""

# %%
a="hello world"
print(a[2])
print(a[-1:])
print(a[-3:])
print(a[2:4])
# Out:
# l
# d
# rld
# ll

# %%
a="Ramesh"
print(a.upper())
print(a.lower())
# Out:
# RAMESH
# ramesh

# %%
c=' ramesh '
print(c.rstrip())
print(c.lstrip())
# Out:
#  ramesh
# ramesh

# %%
a="i am ramesh completed bca"
print(a.split(" "))
# Out:
# ['i', 'am', 'ramesh', 'completed', 'bca']

# %%
a="hello"
b='world'
print(a+b)
c=a+b
print(c)
a+=b
print(a)
# Out:
# helloworld
# helloworld
# helloworld
