# %% [markdown]
# python
#
# variable are container for storing  data values . a variable created moment you first assing a value.

# %%
my_name="ramesh"
print(my_name)
MY_AGE=20
print(MY_AGE)
print(type(my_name))
print(type(MY_AGE))
# Out:
# ramesh
# 20
# <class 'str'>
# <class 'int'>

# %%
my_name='ramesh'
MY_NAME="RAMESH"
print(my_name)
print(MY_NAME)
# Out:
# ramesh
# RAMESH

# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %%
a,b,c=33,"ramesh",22.4
print(a)
print(b)
print(c)
# Out:
# 33
# ramesh
# 22.4

# %%
a=int(22.0)
b=str(33.0)
c=float(55)
d=complex(44)
print(a,b,c,d)
# Out:
# 22 33.0 55.0 (44+0j)

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a=10
del a

# %%
a=100
b=200
b=a
a=b
print(a,b)
# Out:
# 100 100

# %%
a,b=100,200
a,b=b,a
print(a,b)
# Out:
# 200 100

# %%
a="ramesh"
print(len(a))
# Out:
# 6
