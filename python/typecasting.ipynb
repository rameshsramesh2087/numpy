# %%
a=int(22)
b=str(44.4)
c=float(44)
d=complex(33.3)
print(a)
print(b)
print(c)
print(d)
# Out:
# 22
# 44.4
# 44.0
# (33.3+0j)

# %%
a=33
a=float(a)
print(a)
# Out:
# 33.0

# %%
a="ramesh"
print(type(a))
# Out:
# <class 'str'>

# %%
del a

# %%
a="hello world"
print(len(a))
# Out:
# 11

# %%
c=len(a)
print(c)
# Out:
# 11
