# %% [markdown]
# local variable

# %%
food="rice"
def order():
    food="curd rice"
    print("my order is :",food)
order()  
print(food)
# Out:
# my order is : curd rice
# rice

# %% [markdown]
# enclosing

# %%
def flipkart():
    discount=10
    def order():
        product="mobile"
        print(f"my order:{product}and discount percentage:{discount}")
    order() 
flipkart()
# Out:
# my order:mobileand discount percentage:10

# %% [markdown]
# global variable

# %%
name="ramesh"
def invitation():
    print(f"welcome {name} in our home marriage")
def profile():
    print("welcome",name)

invitation()
profile() 
print(name)
# Out:
# welcome ramesh in our home marriage
# welcome ramesh
# ramesh

# %% [markdown]
# build in variable

# %%
print(__file__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(__file__)
#
# NameError: name '__file__' is not defined

# %%
delivery_product="zepto"

def hotal():
    item='briyani'
    def order():
        quantity=2
        print(f"order food-->{item}--->quantity:{quantity}")
hotal()
order()
# Out:
# order food-->rice--->quantity:2

# %%
delivery_partner="zepto" #------->global variable

def electronic_shope():
    product="trimmer"#-------->local variable without(nested function)/with nested function enclosed variable
    def order():
        quantity=1
        date="22/2/2027"
        print(f"my order:{product}\nquant:{quantity}\ndelivery_date:{date}")
        print(f"delivery_partner:{delivery_partner}")
    order()
electronic_shope()
# Out:
# my order:trimmer
# quant:1
# delivery_date:22/2/2027
# delivery_partner:zepto
