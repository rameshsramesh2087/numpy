# %%
# comparison -------> comparison operator used to compare two value return true and flase

a=33
b=22
c=22
print(a==b)
print(c==b)
# Out:
# False
# True

# %%
print(a!=b)
print(a!=c)
# Out:
# True
# True

# %%
print(a>c)
print(c>b)
# Out:
# True
# False

# %%
print(100>=101)
print(101>=100)
# Out:
# False
# True

# %%
print(33<=31)
print(31<=33)
# Out:
# False
# True
