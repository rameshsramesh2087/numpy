# %%
print(22>33 and 44!=33)
print(44>=33 and 55<=100)
# Out:
# False
# True

# %%
print(2==3 or 3==3)
print(44==5 or 20>21)
# Out:
# True
# False

# %%
print(not(33==33 and 55>50))
print(not(33>50 or 44>55))
# Out:
# False
# True
