# %%
# arithmetic operator
a=10
b=20
print(a+b)
print(a-b)
# Out:
# 30
# -10

# %%
print(12/3)
print(12//3)
print(12%3)
print(12*3)
print(12**3)
# Out:
# 4.0
# 4
# 0
# 36
# 1728

# %%
print(9**3)
# Out:
# 729

# %%
print(3**3)
# Out:
# 27
