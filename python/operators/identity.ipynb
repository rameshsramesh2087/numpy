# %%
# identity ---->operator used to compare the object ,not if they are equal ,but it check the memory location
a=22
b=22
print(a is b)
# Out:
# True

# %%
a=257
b=257
print(a is b)
# Out:
# False

# %%
a=["ramesh","dinesh"]
b=["ramesh","dinesh"]
print(a is b)
print(a is not b)
# Out:
# False
# True
