# %%
# assignment operator
a=33
print(a)
# Out:
# 33

# %%
a+=2 #a=a+b
print(a)
# Out:
# 37

# %%
a-=2 #a=a-2
print(a)
# Out:
# 35

# %%
a/=2 #a=a/2
print(a)
# Out:
# 17.5

# %%
a//=2 #a=a//2
print(a)
# Out:
# 8.0

# %%
a**=3 #a=a**2
print(a)
# Out:
# 512.0

# %%
a%=2 #a=a%b
print(a)
# Out:
# 0.0
