# %%
a=22
print(type(a))
print(type(float(a)))
a=float(a)
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %%
a='33'
b='44'
print(a+b)
print(int(a)+int(b))
print(float(a)+float(b))
# Out:
# 3344
# 77
# 77.0

# %%
s='33'
print(float(s))
# Out:
# 33.0

# %%
a=33
print(str(a))
a=str(a)
print(type(a))
# Out:
# 33
# <class 'str'>
