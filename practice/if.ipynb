# %%
purchase_am=int(input('enter amount :'))
tax=purchase_am * 0.18
total=purchase_am + tax
print('total price:',total)

if total >1000:
    discount= total *0.10
    total-=discount
print(f"dicount amount:{discount} -",total)
# Out:
# total price: 11800.0
# dicount amount:1180.0 - 10620.0

# %%
age=int(input('enter your age:'))
student=(str(input('enter your status student or not(yes or no):')))

if age>=60 and age<=100 or student=="yes":
    print('yes discount')
else:
    print('no discount')
# Out:
# yes discount
